# %% [markdown]
# ##  <a href="https://www.outreachy.org/outreachy-may-2021-internship-round/communities/firefox-data-team/#identifying-usage-personalities-in-firefox">Outreachy - Identifying Usage Personalities In Firefox </a>
#
# By: Shemika Lamare

# %% [markdown]
# ## Instructions
# Task 1
# <ul>
# <li> Load the data into R or Python
#     Notebooks (e.g. Jupyter) make us smile, but scripts work too.</li>
#
# <li>Perform exploratory data analysis.
#         Be verbose as to what you are looking at and why.
#         Keep in mind the primary task below.</li>
# <li>Perform data cleaning, if necessary.
#         Again, explain your methodology and reasoning behind it.</li>
# <li><b>Primary Task - Answer the following questions:
#         Which single field in dataset.csv best describes the SalePrice field?
#         Why did you choose this field? Please thoroughly explain your reasoning.
# </ul>
# Additional Information:
# <ul>
# <li>Visualizations make the world a better place! Use them liberally.</li>
# <li>Show your code as much as possible.</li>
# <li>Please also explain your code and your thinking process thoroughly and articulately.</li>
# <li>Write in English as well as in code.</li>
# <li>3rd party libraries are fine. Just make sure to describe why and how you are using them.</li>
# </ul>

# %% [markdown]
# # Loading Libraries & Data

# %%
#importing libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib as mpl 
# %matplotlib inline

# %%
#importing data and making into a dataframe (df)
df = pd.read_csv('/Users/shemikalamare/outreachy-mozilla/initial_contribution/dataset.csv')

# %% [markdown]
# # Inspecting Data

# %%
#preview dataset
pd.set_option("display.max.columns", None) # see all columns
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#review shape of dataset
df.shape
# Out:
# (1460, 81)

# %%
#review columns to consider features and prediction questions
list(df.columns)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
#understand basic info on dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#review basic stats about dataset
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
#reviewing stats to better understand string columns
df.describe(include=np.object)
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %% [markdown]
# # Data Cleaning

# %%
pd.isnull(df).sum() #checking to see which categories have null values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# <b>Data is clean</b>
# <br>
# - Columns have names in Camel Case
# - Rows all have a value or NaN for missing values
# - Data is standarzied and has an index
# - Looking into trends will help see if there are any outliers that may mean some of the data has'incorrect values'(typos)

# %% [markdown]
# # Visuals of Findings

# %%
#since our focus is on SalePrice I want to see the stats specific to it
df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#since our focus is on SalePrice I am finding which columns best correlate with it so I can narrow down the dataset
df[df.columns[1:]].corr()['SalePrice'][:].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# Dataset with .50 and higher --> now called <b>select_df </b>
# - OverallQual      0.790982
# - GrLivArea        0.708624
# - GarageCars       0.640409
# - GarageArea       0.623431
# - TotalBsmtSF      0.613581
# - 1stFlrSF         0.605852
# - FullBath         0.560664
# - TotRmsAbvGrd     0.533723
# - YearBuilt        0.522897
# - YearRemodAdd     0.507101

# %%
#Create a dataframe of select columns that I would like to graph and look at (.50 or higher correlation w/ SalePrice)
select_df = df[["SalePrice", 
                "OverallQual",
                "GrLivArea", 
                "GarageCars", 
                "TotalBsmtSF",
                "1stFlrSF",
                "FullBath",
                "TotRmsAbvGrd",
                "YearBuilt",
                "YearRemodAdd"]]

# %%
#descriptive info on numerical data
select_df.describe()
# Out:
#            SalePrice  OverallQual    GrLivArea   GarageCars  TotalBsmtSF  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   180921.195890     6.099315  1515.463699     1.767123  1057.429452
# std     79442.502883     1.382997   525.480383     0.747315   438.705324
# min     34900.000000     1.000000   334.000000     0.000000     0.000000
# 25%    129975.000000     5.000000  1129.500000     1.000000   795.750000
# 50%    163000.000000     6.000000  1464.000000     2.000000   991.500000
# 75%    214000.000000     7.000000  1776.750000     2.000000  1298.250000
# max    755000.000000    10.000000  5642.000000     4.000000  6110.000000
#
#           1stFlrSF     FullBath  TotRmsAbvGrd    YearBuilt  YearRemodAdd
# count  1460.000000  1460.000000   1460.000000  1460.000000   1460.000000
# mean   1162.626712     1.565068      6.517808  1971.267808   1984.865753
# std     386.587738     0.550916      1.625393    30.202904     20.645407
# ...

# %%
#viewing dataset with select data based on .50 correlation or higher,
#ordered by highest to lowest SalePrice
select_df.sort_values(by='SalePrice', ascending=False)
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  1stFlrSF  \
# 691      755000           10       4316           3         2444      2444
# 1182     745000           10       4476           3         2396      2411
# 1169     625000           10       3627           3         1930      1831
# 898      611657            9       2364           3         2330      2364
# 803      582933            9       2822           3         1734      1734
# ...         ...          ...        ...         ...          ...       ...
# 30        40000            4       1317           1          649       649
# 533       39300            1        334           0            0       334
# 968       37900            3        968           0          600       600
# 916       35311            2        480           1          480       480
# 495       34900            4        720           0          720       720
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# ...

# %%
# using select_df to create correlation map
df_small = select_df.iloc[:,:50]
correlation_mat = df_small.corr()
sns.heatmap(correlation_mat, annot = True)

plt.show()

# %%
select_df.boxplot(column='SalePrice', by='OverallQual')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='GrLivArea')

# %%
select_df.plot.scatter(x='SalePrice', y='GarageCars')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='TotalBsmtSF')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='1stFlrSF')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='FullBath')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='TotRmsAbvGrd')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='YearBuilt')
plt.show()

# %%
select_df.plot.scatter(x='SalePrice', y='YearRemodAdd')
plt.show()

# %%
select_df.hist()
plt.tight_layout()

# %%
columns = ['SalePrice']
df[columns].plot.box()
plt.xticks(rotation='vertical')
# Out:
# (array([1]), <a list of 1 Text major ticklabel objects>)

# %% [markdown]
# # Conclusion - Primary Task
# Which single field in dataset.csv best describes the SalePrice field? Why did you choose this field? Please thoroughly explain your reasoning.

# %% [markdown]
# - If our focus point wasn't SalePrice I would spend more time digging into the other columns and seeing what information I could pull from them.
# - I found the correlation between SalePrice and the other features, and created a dataframe of just that 'select_data. I chose the select data based on a correlation of.50 or higher correlation. I focused on those features to dive deeper into them.
# - As for which best describes the SalePrice field it would be Overall Condition. I am basing this on the correlation. As well as contextually it makes sense that the Overall Condition would be a big factor in Sale Price. (using the dataset explanations to better understand the categories)
